# %%
import pandas as pd
import numpy as np

INPUT_PATH = "C:/Users/u00378/Desktop/tcc_est_unb"
#INPUT_PATH = "C:/Users/Igor/Desktop/TCC"

df_ = pd.read_csv(f'{INPUT_PATH}/dados/datatran2007.csv', encoding='latin1', on_bad_lines='skip', sep =';',\
                  dtype={'br':'object','km':'object'}, na_values='(null)')

# %%
a = np.array([178489., 265086., 289199., 193456., 194575., 212953., 195856.,\
              296674., 251529., 230492., 219715., 321979., 312903.])

# %%
df_[df_['id'].isin(a)]
# Out:
#             id data_inversa dia_semana   horario  uf   br     km
# 3344    178489   11/01/2007     Quinta  11:00:00  MG  381    421  \
# 15340   193456   17/02/2007     Sábado  18:55:00  RR  401    3.9
# 16321   194575   20/02/2007      Terça  15:00:00  PA  316     23
# 17381   195856   19/02/2007    Segunda  16:10:00  BA  101     45
# 31191   212953   08/04/2007    Domingo  16:40:00  BA  324  516.8
# 36724   219715   16/04/2007    Segunda  06:35:00  BA  324    525
# 45485   230492   18/05/2007      Sexta  07:35:00  RS  386  297.6
# 62695   251529   10/07/2007      Terça  06:50:00  MG  381    249
# 73910   265086   11/08/2007     Sábado  20:15:00  RN  101     96
# 95132   289199   12/10/2007      Sexta  05:55:00  MG  135  624.6
# 101816  296674   27/10/2007     Sábado  17:00:00  DF   20   15.9
# 116744  312903   11/12/2007      Terça  11:00:00  MG  116    521
# 124255  321979   27/12/2007     Quinta  09:20:00  RS  116    254
#
# ...
